# %%
import os
import numpy as np
import env
import pandas as pd
import acquire_copy as acq

import matplotlib as plt
import seaborn as  sb
import scipy.stats as stats
from pydataset import data
from sklearn.model_selection import train_test_split

# %%
iris = acq.get_iris_data()
telco = acq.get_telco_data()
titanic = acq.get_titanic_data()

# %% [markdown]
# # Using the Iris Data:

# %% [markdown]
# Exercise 1.1. Use the function defined in acquire.py to load the iris data.

# %%
print(iris.head())
print(iris.info())
# Out:
#    species_id  measurement_id  sepal_length  sepal_width  petal_length  \
# 0           1               1           5.1          3.5           1.4
# 1           1               2           4.9          3.0           1.4
# 2           1               3           4.7          3.2           1.3
# 3           1               4           4.6          3.1           1.5
# 4           1               5           5.0          3.6           1.4
#
#    petal_width species_name
# 0          0.2       setosa
# 1          0.2       setosa
# 2          0.2       setosa
# 3          0.2       setosa
# 4          0.2       setosa
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   species_id      150 non-null    int64
#  1   measurement_id  150 non-null    int64
#  2   sepal_length    150 non-null    float64
# ...

# %% [markdown]
# Exercise 1.2: Drop the species_id and measurement_id columns.

# %%
iris = iris.drop(columns=['species_id', 'measurement_id'])
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width species_name
# 0             5.1          3.5           1.4          0.2       setosa
# 1             4.9          3.0           1.4          0.2       setosa
# 2             4.7          3.2           1.3          0.2       setosa
# 3             4.6          3.1           1.5          0.2       setosa
# 4             5.0          3.6           1.4          0.2       setosa
# 5             5.4          3.9           1.7          0.4       setosa
# 6             4.6          3.4           1.4          0.3       setosa
# 7             5.0          3.4           1.5          0.2       setosa
# 8             4.4          2.9           1.4          0.2       setosa
# 9             4.9          3.1           1.5          0.1       setosa
# 10            5.4          3.7           1.5          0.2       setosa
# 11            4.8          3.4           1.6          0.2       setosa
# ...

# %% [markdown]
# Exercise 1.3: Rename the species_name column to just species.

# %%
iris= iris.rename(columns={'species_name': 'species'})
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# ...

# %% [markdown]
# Exercise 1.4: Create dummy variables of the species name and concatenate onto the iris dataframe. (This is for practice, we don't always have to encode the target, but if we used species as a feature, we would need to encode it).

# %%
foofighters = pd.get_dummies(iris['species'], drop_first= True)

pd.concat([iris, foofighters], axis=1)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species  \
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# ...

# %% [markdown]
# Exercise 1.5: Create a function named prep_iris that accepts the untransformed iris data, and returns the data with the transformations above applied.

# %%
def prep_iris(iris):
    """This function preps data in the iris csv (via the get_iris_data() function
    in acquire_copy) for future use"""
    iris = iris.drop(columns=['species_id', 'measurement_id'])
    iris = iris.rename(columns={'species_name':'species'})
    foofighters = pd.get_dummies(iris['species'], drop_first= True)
    iris=  pd.concat([iris, foofighters], axis=1)
    
    return iris

iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# ...

# %% [markdown]
# # Using the Titanic dataset

# %% [markdown]
# Exercise 2.1: Use the function defined in acquire.py to load the Titanic data.

# %%
# I've already called/renamed my variables from my acq module, so I can go right into 
# working with it

titanic.info()
print(titanic.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   passenger_id  891 non-null    int64
#  1   survived      891 non-null    int64
#  2   pclass        891 non-null    int64
#  3   sex           891 non-null    object
#  4   age           714 non-null    float64
#  5   sibsp         891 non-null    int64
#  6   parch         891 non-null    int64
#  7   fare          891 non-null    float64
#  8   embarked      889 non-null    object
#  9   class         891 non-null    object
#  10  deck          203 non-null    object
#  11  embark_town   889 non-null    object
#  12  alone         891 non-null    int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 97.5+ KB
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# ...

# %% [markdown]
# Exercise 2.2: Drop any unnecessary, unhelpful, or duplicated columns.

# %%
# These columns are redundant, so I'm dropping all of them

titanic=titanic.drop(columns=['embarked', 'class', 'passenger_id', 'deck'])
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  embark_town  alone
# 0           0       3    male  22.0      1      0   7.2500  Southampton      0
# 1           1       1  female  38.0      1      0  71.2833    Cherbourg      0
# 2           1       3  female  26.0      0      0   7.9250  Southampton      1
# 3           1       1  female  35.0      1      0  53.1000  Southampton      0
# 4           0       3    male  35.0      0      0   8.0500  Southampton      1
# ..        ...     ...     ...   ...    ...    ...      ...          ...    ...
# 886         0       2    male  27.0      0      0  13.0000  Southampton      1
# 887         1       1  female  19.0      0      0  30.0000  Southampton      1
# 888         0       3  female   NaN      1      2  23.4500  Southampton      0
# 889         1       1    male  26.0      0      0  30.0000    Cherbourg      1
# 890         0       3    male  32.0      0      0   7.7500   Queenstown      1
#
# [891 rows x 9 columns]

# %% [markdown]
# Exercise 2.3: Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the dataframe.

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare  embark_town  alone
# 0         0       3    male  22.0      1      0   7.2500  Southampton      0
# 1         1       1  female  38.0      1      0  71.2833    Cherbourg      0
# 2         1       3  female  26.0      0      0   7.9250  Southampton      1
# 3         1       1  female  35.0      1      0  53.1000  Southampton      0
# 4         0       3    male  35.0      0      0   8.0500  Southampton      1

# %%
titanic.dtypes
# Out:
# survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embark_town     object
# alone            int64
# dtype: object

# %%
jack_in_thewater= pd.get_dummies(titanic[['sex', 'embark_town']], drop_first=True)
pd.concat([titanic, jack_in_thewater], axis=1)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  embark_town  \
# 0           0       3    male  22.0      1      0   7.2500  Southampton
# 1           1       1  female  38.0      1      0  71.2833    Cherbourg
# 2           1       3  female  26.0      0      0   7.9250  Southampton
# 3           1       1  female  35.0      1      0  53.1000  Southampton
# 4           0       3    male  35.0      0      0   8.0500  Southampton
# ..        ...     ...     ...   ...    ...    ...      ...          ...
# 886         0       2    male  27.0      0      0  13.0000  Southampton
# 887         1       1  female  19.0      0      0  30.0000  Southampton
# 888         0       3  female   NaN      1      2  23.4500  Southampton
# 889         1       1    male  26.0      0      0  30.0000    Cherbourg
# 890         0       3    male  32.0      0      0   7.7500   Queenstown
#
#      alone  sex_male  embark_town_Queenstown  embark_town_Southampton
# ...

# %% [markdown]
# Exercise 2.4: Create a function named prep_titanic that accepts the raw titanic data, and returns the data with the transformations above applied.

# %%
def prep_titanic(titanic):
    titanic=titanic.drop(columns=['embarked', 'class', 'passenger_id', 'deck'])
    titanic['age'] = ['age'].fillna(titanic['age'].mean())
    titanic['embark_town'] = titanic['embark_town'].fillna(titanic['age'].mean())
    titanic=  pd.concat([titanic, (pd.get_dummies(titanic['sex', 'embark_town']))], axis = 1)
    titanic = titanic.drop(columns=['embark_town', 'sex'])
    return titanic

titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  embark_town  alone
# 0           0       3    male  22.0      1      0   7.2500  Southampton      0
# 1           1       1  female  38.0      1      0  71.2833    Cherbourg      0
# 2           1       3  female  26.0      0      0   7.9250  Southampton      1
# 3           1       1  female  35.0      1      0  53.1000  Southampton      0
# 4           0       3    male  35.0      0      0   8.0500  Southampton      1
# ..        ...     ...     ...   ...    ...    ...      ...          ...    ...
# 886         0       2    male  27.0      0      0  13.0000  Southampton      1
# 887         1       1  female  19.0      0      0  30.0000  Southampton      1
# 888         0       3  female   NaN      1      2  23.4500  Southampton      0
# 889         1       1    male  26.0      0      0  30.0000    Cherbourg      1
# 890         0       3    male  32.0      0      0   7.7500   Queenstown      1
#
# [891 rows x 9 columns]

# %% [markdown]
# # Using the Telco dataset
#
#    Exercise 3.1 Use the function defined in acquire.py to load the Telco data.

# %%
telco.head()
# Out:
#    payment_type_id  internet_service_type_id  contract_type_id customer_id  \
# 0                2                         1                 2  0002-ORFBO
# 1                2                         1                 1  0003-MKNFE
# 2                1                         2                 1  0004-TLHLJ
# 3                1                         2                 1  0011-IGKFF
# 4                2                         2                 1  0013-EXCHZ
#
#    gender  senior_citizen partner dependents  tenure phone_service  ...  \
# 0  Female               0     Yes        Yes       9           Yes  ...
# 1    Male               0      No         No       9           Yes  ...
# 2    Male               0      No         No       4           Yes  ...
# 3    Male               1     Yes         No      13           Yes  ...
# 4  Female               1     Yes         No       3           Yes  ...
#
#   tech_support streaming_tv streaming_movies paperless_billing  \
# ...

# %%
# Checking to see what type of data I'm working with

telco.dtypes
# Out:
# payment_type_id               int64
# internet_service_type_id      int64
# contract_type_id              int64
# customer_id                  object
# gender                       object
# senior_citizen                int64
# partner                      object
# dependents                   object
# tenure                        int64
# phone_service                object
# multiple_lines               object
# online_security              object
# online_backup                object
# device_protection            object
# tech_support                 object
# streaming_tv                 object
# streaming_movies             object
# paperless_billing            object
# monthly_charges             float64
# total_charges                object
# churn                        object
# contract_type                object
# internet_service_type        object
# payment_type                 object
# dtype: object

# %% [markdown]
# Exercise 3.2: Drop any unnecessary, unhelpful, or duplicated columns. This could mean dropping foreign key columns but keeping the corresponding string values, for example.

# %%
# Checking to see if I have any null values running through my df

telco.isna().sum()

#Good to go
# Out:
# payment_type_id             0
# internet_service_type_id    0
# contract_type_id            0
# customer_id                 0
# gender                      0
# senior_citizen              0
# partner                     0
# dependents                  0
# tenure                      0
# phone_service               0
# multiple_lines              0
# online_security             0
# online_backup               0
# device_protection           0
# tech_support                0
# streaming_tv                0
# streaming_movies            0
# paperless_billing           0
# monthly_charges             0
# total_charges               0
# churn                       0
# contract_type               0
# internet_service_type       0
# payment_type                0
# dtype: int64

# %%
# Dropping foreign keys

telco.drop(columns=['payment_type_id', 'internet_service_type_id', 'contract_type_id']).head()
# Out:
#   customer_id  gender  senior_citizen partner dependents  tenure  \
# 0  0002-ORFBO  Female               0     Yes        Yes       9
# 1  0003-MKNFE    Male               0      No         No       9
# 2  0004-TLHLJ    Male               0      No         No       4
# 3  0011-IGKFF    Male               1     Yes         No      13
# 4  0013-EXCHZ  Female               1     Yes         No       3
#
#   phone_service multiple_lines online_security online_backup  ...  \
# 0           Yes             No              No           Yes  ...
# 1           Yes            Yes              No            No  ...
# 2           Yes             No              No            No  ...
# 3           Yes             No              No           Yes  ...
# 4           Yes             No              No            No  ...
#
#   tech_support streaming_tv streaming_movies paperless_billing  \
# 0          Yes          Yes               No               Yes
# ...

# %% [markdown]
# Exercise 3.3: Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the dataframe.

# %%
# This list will return all of my categorical types 

reading_rainbow = list(telco.select_dtypes(include= ['O']))
reading_rainbow
# Out:
# ['customer_id',
#  'gender',
#  'partner',
#  'dependents',
#  'phone_service',
#  'multiple_lines',
#  'online_security',
#  'online_backup',
#  'device_protection',
#  'tech_support',
#  'streaming_tv',
#  'streaming_movies',
#  'paperless_billing',
#  'total_charges',
#  'churn',
#  'contract_type',
#  'internet_service_type',
#  'payment_type']

# %%
# This list will return all of my non-object types. I'll use .tolist instead of list() just
# for funsies

count_it_up=telco.select_dtypes(exclude= ['O']).columns.tolist()
count_it_up
# Out:
# ['payment_type_id',
#  'internet_service_type_id',
#  'contract_type_id',
#  'senior_citizen',
#  'tenure',
#  'monthly_charges']

# %% [markdown]
# Exercise 3.4: Create a function named prep_telco that accepts the raw telco data, and returns the data with the transformations above applied.

# %%
def prep_df(df):
    """This (revised) function preps data from the df csv (acquired via the get_df_data() function in 
    acquire_copy and preps it for future use."""
    
    # drop unnecessary/redundant columns
    # df=df.drop(columns=['internet_service_type_id', 'payment_type_id', 'contract_type_id'],    inplace=True)
    
    
    # convert binary cat variables to numeric
    df['churn_bin'] = df['churn'].map({'Yes': 1, 'No': 0})
    df['gender_bin'] = df['gender'].map({'Female': 1, 'Male': 0})
    df['partner_bin'] = df['partner'].map({'Yes': 1, 'No': 0})
    df['dependents_bin'] = df['dependents'].map({'Yes': 1, 'No': 0})
    df['paperless_billing_bin'] = df['paperless_billing'].map({'Yes': 1, 'No': 0})
    df['phone_service_bin'] = df['phone_service'].map({'Yes': 1, 'No': 0})
    
    # Dummy variables for enby cat variables
    radioshack= pd.get_dummies( df[[   'tech_support', \
                                       'multiple_lines', \
                                       'tech_support', \
                                       'payment_type', \
                                       'internet_service_type',\
                                       'contract_type',\
                                      ]], drop_first= True)
    df= pd.concat([df, radioshack], axis=1)
    
    return df

# %% [markdown]
# # Split your data
#
# Exercise 4.1: Write a function to split your data into train, test and validate datasets. Add this function to prepare.py.

# %%
def tvt_split(df, target):
     # 80% train_validate, 20% test
# then of the 80% train_validate: 30% validate, 70% train.
# Final split will be 60/20/20 
  
    train, test = train_test_split(df, test_size=.2, random_state=123, stratify=df[target])
    train, val = train_test_split(train, test_size=.30, random_state=123, stratify=train[target])

    return train,val,test

# %% [markdown]
# Exercise 4.2: Run the function in your notebook on the Iris dataset, returning 3 datasets, train_iris, validate_iris and test_iris.
# Exercise 4.3: Run the function on the Titanic dataset, returning 3 datasets, train_titanic, validate_titanic and test_titanic.
# Exercise 4.4: Run the function on the Telco dataset, returning 3 datasets, train_telco, validate_telco and test_telco.

# %%
# Iris

tvt_split(iris, 'species')
# Out:
# (     sepal_length  sepal_width  petal_length  petal_width     species
#  79            5.7          2.6           3.5          1.0  versicolor
#  36            5.5          3.5           1.3          0.2      setosa
#  133           6.3          2.8           5.1          1.5   virginica
#  95            5.7          3.0           4.2          1.2  versicolor
#  18            5.7          3.8           1.7          0.3      setosa
#  139           6.9          3.1           5.4          2.1   virginica
#  20            5.4          3.4           1.7          0.2      setosa
#  31            5.4          3.4           1.5          0.4      setosa
#  6             4.6          3.4           1.4          0.3      setosa
#  115           6.4          3.2           5.3          2.3   virginica
#  91            6.1          3.0           4.6          1.4  versicolor
#  145           6.7          3.0           5.2          2.3   virginica
# ...

# %%
# Titanic

tvt_split(titanic, 'survived')
# Out:
# (     survived  pclass     sex   age  sibsp  parch      fare  embark_town  \
#  583         0       1    male  36.0      0      0   40.1250    Cherbourg
#  165         1       3    male   9.0      0      2   20.5250  Southampton
#  50          0       3    male   7.0      4      1   39.6875  Southampton
#  259         1       2  female  50.0      0      1   26.0000  Southampton
#  306         1       1  female   NaN      0      0  110.8833    Cherbourg
#  ..        ...     ...     ...   ...    ...    ...       ...          ...
#  313         0       3    male  28.0      0      0    7.8958  Southampton
#  636         0       3    male  32.0      0      0    7.9250  Southampton
#  222         0       3    male  51.0      0      0    8.0500  Southampton
#  485         0       3  female   NaN      3      1   25.4667  Southampton
#  744         1       3    male  31.0      0      0    7.9250  Southampton
#
#       alone
#  583      1
#  165      0
#  50       0
#  259      0
# ...

# %%
# Telco

tvt_split(telco, 'churn')
# Out:
# (      payment_type_id  internet_service_type_id  contract_type_id customer_id  \
#  5310                3                         1                 3  7503-MIOGA
#  3790                4                         1                 3  5329-KRDTM
#  4398                1                         2                 2  6199-IWKGC
#  2635                1                         1                 1  3748-FVMZZ
#  2986                2                         1                 1  4280-DLSHD
#  ...               ...                       ...               ...         ...
#  6230                1                         2                 3  8809-RIHDD
#  356                 1                         1                 1  0523-VNGTF
#  2128                1                         2                 2  3058-HJCUY
#  3586                2                         1                 2  5081-NWSUP
#  6817                1                         2                 1  9681-KYGYB
#
# ...
